# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
for x in range(3):
    print(x)
a=range(10)
print(a[0])
# Out:
# 0
# 1
# 2
# 0

# %%
plot(random_sample(100))
